# %%
import pandas as pd
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import  train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# %%
x_train = train[['LotArea']]
y_train = train[["SalePrice"]]
x_test = test[['LotArea']]

selected_model = LinearRegression()
selected_model.fit(x_train, y_train)

y_pred = selected_model.predict(x_test)

# The coefficients
print("Coefficients: \n", selected_model.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(x_test, y_test, color="black")
plt.xlabel("Lot Sizes")
plt.ylabel("Predicted Prices")
plt.title("Lot Size vs Predicted House Prices")
plt.plot(x_test, y_pred, color="blue", linewidth=3)
plt.show()
# Out:
# Coefficients:
#  [[2.09997195]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11132\2934268491.py in <module>
#      11 print("Coefficients: \n", selected_model.coef_)
#      12 # The mean squared error
# ---> 13 print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
#      14 # The coefficient of determination: 1 is perfect prediction
#      15 print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
#
# NameError: name 'y_test' is not defined

# %%
x_data = train[['LotArea']]
y_data = train[["SalePrice"]]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

selected_model = LinearRegression()
selected_model.fit(x_train, y_train)

y_pred = selected_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)

# The coefficients
print("Coefficients: ", selected_model.coef_)
# The intercept
print("Intercept: ", selected_model.intercept_)
# The mean squared error
print("Mean squared error: %.3f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.3f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(x_test, y_test, color="black")
plt.xlabel("Lot Sizes")
plt.ylabel("Predicted Prices")
plt.title("Lot Size vs Predicted House Prices")
plt.plot(x_test, y_pred, color="blue", linewidth=3)
plt.show()
# Out:
# Coefficients:  [[1.91162168]]
# Intercept:  [161006.99034068]
# Mean squared error: 7189094014.826
# Coefficient of determination: 0.063

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
train = train.drop(train['LotArea'].nlargest(50).index)

train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1410 rows x 81 columns]

# %%
x_data = train[['LotArea']]
y_data = train[["SalePrice"]]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

selected_model = LinearRegression()
selected_model.fit(x_train, y_train)

y_pred = selected_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)

# The coefficients
print("Coefficients: ", selected_model.coef_)
# The intercept
print("Intercept: ", selected_model.intercept_)
# The mean squared error
print("Mean squared error: %.3f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.3f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(x_test, y_test, color="black")
plt.xlabel("Lot Sizes")
plt.ylabel("Predicted Prices")
plt.title("Lot Size vs Predicted House Prices")
plt.plot(x_test, y_pred, color="blue", linewidth=3)
plt.show()
# Out:
# Coefficients:  [[9.59707797]]
# Intercept:  [87302.68268292]
# Mean squared error: 5777787739.143
# Coefficient of determination: 0.170

# %%
train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.013242    -0.022049 -0.007969    -0.021692
# MSSubClass     0.013242    1.000000    -0.441874 -0.428510     0.037870
# LotFrontage   -0.022049   -0.441874     1.000000  0.678308     0.248387
# LotArea       -0.007969   -0.428510     0.678308  1.000000     0.228265
# OverallQual   -0.021692    0.037870     0.248387  0.228265     1.000000
# OverallCond    0.015964   -0.057639    -0.064495 -0.022067    -0.102001
# YearBuilt     -0.019521    0.029179     0.149304  0.088547     0.586100
# YearRemodAdd  -0.025888    0.046403     0.087862  0.066513     0.558000
# MasVnrArea    -0.064012    0.026655     0.189275  0.156747     0.400547
# BsmtFinSF1    -0.005627   -0.080345     0.154921  0.178486     0.217906
# BsmtFinSF2     0.007080   -0.061342     0.049561  0.086832    -0.063933
# BsmtUnfSF     -0.011281   -0.142774     0.169485  0.121336     0.318566
# 3SsnPorch        -0.030216 -0.006696  0.000859  0.016789  0.019322   0.049735
# ScreenPorch       1.000000  0.065924  0.034608  0.024314  0.011389   0.096794
# PoolArea          0.065924  1.000000  0.034941 -0.008088 -0.056099   0.107838
# MiscVal           0.034608  0.034941  1.000000 -0.007440  0.004977  -0.021222
# MoSold            0.024314 -0.008088 -0.007440  1.000000 -0.150039   0.059338
# YrSold            0.011389 -0.056099  0.004977 -0.150039  1.000000  -0.018173
# SalePrice         0.096794  0.107838 -0.021222  0.059338 -0.018173   1.000000
#
# [38 rows x 38 columns]

# %%
x_data = train[['OverallQual']]

y_data = train[["SalePrice"]]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

selected_model = LinearRegression()
selected_model.fit(x_train, y_train)

y_pred = selected_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)

# The coefficients
print("Coefficients: ", selected_model.coef_)
# The intercept
print("Intercept: ", selected_model.intercept_)
# The mean squared error
print("Mean squared error: %.3f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.3f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, color="black")
plt.xlabel("Lot Sizes")
plt.ylabel("Predicted Prices")
plt.title("Lot Size vs Predicted House Prices")
plt.show()
# Out:
# Coefficients:  [[43754.15191917]]
# Intercept:  [-89054.15958653]
# Mean squared error: 2480161004.485
# Coefficient of determination: 0.644

# %%
x_data = train[['LotArea', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath']]
y_data = train[["SalePrice"]]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

selected_model = LinearRegression()
selected_model.fit(x_train, y_train)

y_pred = selected_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)

print("Coefficients: ", selected_model.coef_)
print("Intercept: ", selected_model.intercept_)
print("Mean squared error: %.3f" % mean_squared_error(y_test, y_pred))
print("Coefficient of determination: %.3f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, color="black")
plt.xlabel("X-Values")
plt.ylabel("Predicted Prices")
plt.title("Predicted House Prices - Linear")
plt.show()
# Out:
# Coefficients:  [[2.86681965e+00 2.72405218e+04 3.99986350e+01 5.21160580e+03
#   4.88798550e+01 3.23372310e+03]]
# Intercept:  [-112032.77713527]
# Mean squared error: 1372015623.283
# Coefficient of determination: 0.803

# %%
y = (0.764455110*('LotArea')) + (0.000273129721*('OverallQual')) + (0.408015456*('GrLivArea'))
+ (0.000132914061*('GarageCars')) + (0.327734145*('GarageArea')) + (0.00157417481*('FullBath')) -98021.66094866
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21164\4279151170.py in <module>
# ----> 1 y = (0.764455110*('LotArea')) + (0.000273129721*('OverallQual')) + (0.408015456*('GrLivArea'))
#       2 + (0.000132914061*('GarageCars')) + (0.327734145*('GarageArea')) + (0.00157417481*('FullBath')) -98021.66094866
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# x_data = train[['LotArea', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath']]
x_data = train[['OverallQual']]
y_data = train[["SalePrice"]]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

poly = PolynomialFeatures(degree=3)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

selected_model = LinearRegression()
selected_model.fit(x_train_poly, y_train)

y_pred = selected_model.predict(x_test_poly)

mse = mean_squared_error(y_test, y_pred)

# The coefficients
print("Coefficients: ", selected_model.coef_)
# The intercept
print("Intercept: ", selected_model.intercept_)
# The mean squared error
print("Mean squared error: %.3f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.3f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, color="black")
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Predicted House Prices - Polynomial")
plt.show()
# Out:
# Coefficients:  [[    0.         30981.96540681 -5110.77355724   629.94899956]]
# Intercept:  [23851.78905872]
# Mean squared error: 1966895054.595
# Coefficient of determination: 0.718

# %%
# x_data = train[['LotArea', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath']]
# x_data = train[['OverallQual']]
x_data = train[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath']]
y_data = train[["SalePrice"]]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

poly = PolynomialFeatures(degree=2)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

selected_model = LinearRegression()
selected_model.fit(x_train_poly, y_train)

y_pred = selected_model.predict(x_test_poly)

mse = mean_squared_error(y_test, y_pred)

# The coefficients
print("Coefficients: ", selected_model.coef_)
# The intercept
print("Intercept: ", selected_model.intercept_)
# The mean squared error
print("Mean squared error: %.3f" % mean_squared_error(y_test, y_pred))
# The root mean squared error
print("Root Mean squared error: %.3f" % mean_squared_error(y_test, y_pred, squared=False))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.3f" % r2_score(y_test, y_pred))

plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, color="black")
plt.xlabel("X-Values")
plt.ylabel("Predicted Prices")
plt.title("Predicted House Prices - Polynomial")
plt.show()
# Out:
# Coefficients:  [[ 0.00000000e+00 -1.68917331e+04  2.02229702e+00 -3.48750298e+04
#    4.49049235e+01 -2.64333418e+04  4.16786418e+02  1.23496831e+01
#    6.16649313e+03  1.46616501e+01 -5.14544039e+02 -2.30957948e-02
#    2.41548452e+01 -6.54732835e-02  2.13219466e+01 -1.99290022e+04
#    7.43494683e+01  5.36847598e+03 -4.67508039e-02 -5.22023824e+01
#    3.92407998e+03]]
# Intercept:  [130600.94093229]
# Mean squared error: 1336000826.696
# Root Mean squared error: 36551.345
# Coefficient of determination: 0.826

# %%
import numpy
import matplotlib.pyplot as plt

# %%
x = train["OverallQual"]
y = train["SalePrice"]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 10)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

print(r2_score(y, mymodel(x)))
# Out:
# 0.7092838186785035

# %%
train.corr()["SalePrice"].nlargest(10)
# Out:
# SalePrice       1.000000
# OverallQual     0.805831
# GrLivArea       0.720913
# TotalBsmtSF     0.652292
# GarageCars      0.651074
# GarageArea      0.640401
# 1stFlrSF        0.635066
# FullBath        0.576476
# YearBuilt       0.557843
# TotRmsAbvGrd    0.536289
# Name: SalePrice, dtype: float64

# %%
X = train[["OverallQual"]].values
Y = train[["SalePrice"]].values.reshape(-1, 1)

# %%
class Linear_Regression():

    # Initiating the parameters.
    def __init__(self, learning_rate, no_of_itr):
        self.learning_rate = learning_rate
        self.no_of_itr = no_of_itr

    def fit(self, X, Y):

        # No. of training examples and no. of features.
        self.m, self.n = X.shape     # Number of rows and columns
        # Initiating the weight and bias
        self.w = np.zeros((self.n, 1))
        self.b = 0
        self.X = X
        self.Y = Y

        # Gradient descent for number of iterations.
        for i in range(self.no_of_itr):
            self.update_weights()

    def update_weights(self):
        Y_prediction = self.predict(self.X)

        # Calculating gradients
        dw = -(self.X.T).dot(self.Y - Y_prediction)/self.m

        db = -np.sum(self.Y - Y_prediction)/self.m

        # Updating weights
        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db

    def predict(self, X):
        return X.dot(self.w) + self.b

    def print_weights(self):
        print('Weights for the respective features are :')
        print(self.w)
        print()

        print('Bias value for the regression is:', self.b)
        print()

# %%
model = Linear_Regression(learning_rate=0.03, no_of_itr=30000)
model.fit(X, Y)
model.print_weights()
print("r2 score is:", r2_score(Y, model.predict(X)))

plt.scatter(X, Y)
plt.plot(X, model.predict(X))
plt.xlabel('Quality')
plt.ylabel('Sale Price')
plt.title('Single Linear Regression')
plt.show()
# Out:
# Weights for the respective features are :
# [[44628.76625101]]
#
# Bias value for the regression is: -93256.61170119466
#
# r2 score is: 0.6493639700169126

# %%
x_data = train[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath']].values
y_data = train[["SalePrice"]].values.reshape(-1, 1)

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_data)

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_data, test_size=0.2, random_state=42)

# %%
class Linear_Regression():

    # Initiating the parameters.
    def __init__(self, learning_rate, no_of_itr):
        self.learning_rate = learning_rate
        self.no_of_itr = no_of_itr

    def fit(self, X, Y):

        # No. of training examples and no. of features.
        self.m, self.n = X.shape     # Number of rows and columns
        # Initiating the weight and bias
        self.w = np.zeros((self.n, 1))
        self.b = 0
        self.X = X
        self.Y = Y

        # Implementing the gradient descent.
        for i in range(self.no_of_itr):
            self.update_weights()

    def update_weights(self):
        Y_prediction = self.predict(self.X)

        # Calculating gradients
        dw = -(self.X.T).dot(self.Y - Y_prediction)/self.m

        db = -np.sum(self.Y - Y_prediction)/self.m

        # Updating weights
        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db

    def predict(self, X):
        return X.dot(self.w) + self.b

    def print_weights(self):
        print('Weights for the respective features are :')
        print(self.w)
        print()

        print('Bias value for the regression is:', self.b)
        print()

    def return_weights(self):
        return(self.w)

    def return_bias(self):
        return(self.b)

# %%
model = Linear_Regression(learning_rate=0.02, no_of_itr=7000)
model.fit(x_train, y_train)
model.print_weights()
weights = model.return_weights()
bias = model.return_bias()
print("r2 score is:", r2_score(y_test, model.predict(x_test)))
print("MSE is:", mean_squared_error(y_test, model.predict(x_test)))
print("RMSE is:", mean_squared_error(y_test, model.predict(x_test), squared=False))

plt.scatter(model.predict(x_test), y_test)
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Multiple Linear Regression')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()])

plt.show()
# Out:
# Weights for the respective features are :
# [[36425.79844669]
#  [23726.77998389]
#  [ 3004.73515632]
#  [13617.92308054]
#  [  966.15510664]]
#
# Bias value for the regression is: 177523.17579953032
#
# r2 score is: 0.7899802311786543
# MSE is: 1462440405.7805667
# RMSE is: 38241.867184808936

# %%
y = 36860.58012726(v) + 24026.048208(w) + 9849.75689053(x)
+ 8031.44705966(y) + 330.14378072(z) + 179979.17315961127

v = 'OverallQual'
w = 'GrLivArea'
x = 'GarageCars'
y = 'GarageArea'
z = 'FullBath'
# Out:
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
# C:\Users\bsilver3\AppData\Local\Temp\ipykernel_21164\4168683418.py:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   y = 36860.58012726(v) + 24026.048208(w) + 9849.75689053(x)
# C:\Users\bsilver3\AppData\Local\Temp\ipykernel_21164\4168683418.py:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   y = 36860.58012726(v) + 24026.048208(w) + 9849.75689053(x)
# C:\Users\bsilver3\AppData\Local\Temp\ipykernel_21164\4168683418.py:1: SyntaxWarning: 'float' object is not callable; perhaps you missed a comma?
#   y = 36860.58012726(v) + 24026.048208(w) + 9849.75689053(x)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21164\4168683418.py in <module>
# ----> 1 y = 36860.58012726(v) + 24026.048208(w) + 9849.75689053(x)
#       2 + 8031.44705966(y) + 330.14378072(z) + 179979.17315961127
#       3
#       4 v = 'OverallQual'
#       5 w = 'GrLivArea'
#
# NameError: name 'v' is not defined

# %%
len(weights)
# Out:
# 5

# %%
# x_data = train[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'FullBath']].values
x_data = train[['OverallQual']].values
y_data = train[["SalePrice"]].values.reshape(-1, 1)

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_data)

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y_data, test_size=0.2, random_state=42)

# %%
class Polynomial_Regression():

    # Initiating the parameters.
    def __init__(self, learning_rate, no_of_itr, degree):
        self.learning_rate = learning_rate
        self.no_of_itr = no_of_itr
        self.degree = degree

    def transform(self, X):
        X_transform = np.ones((self.m, 1))
        j = 0
        for j in range(self.degree + 1):
            if j != 0 :
                x_pow = np.power(X, j)
                X_transform = np.append(X_transform, x_pow.reshape(-1, 1), axis = 1 )
        return X_transform

    # def normalize(self, X):
    #     X[:, 1:] = ( X[:, 1:] - np.mean( X[:, 1:], axis = 0 ) ) / np.std( X[:, 1:], axis = 0 )
    #     return X

    def fit(self, X, Y):

        # No. of training examples and no. of features.
        self.m, self.n = X.shape     # Number of rows and columns
        # Initiating the weight and bias
        self.w = np.zeros((self.degree + 1))
        self.b = 0
        self.X = X
        self.Y = Y

        X_transform = self.transform(self.X)
        # X_normalize = self.normalize(X_transform)

        # Implementing the gradient descent.
        for i in range(self.no_of_itr):

        #     self.update_weights()
        #     # Y_prediction = self.predict(self.X)

        #     # error = Y_prediction - self.Y

        #     # # Updating weights
        #     # self.w = self.w - self.learning_rate * (1 / self.m) * np.dot(X_normalize.T, error)
        # return self

            Y_prediction = self.predict(self.X)

            # Calculating gradients
            dw = (X_transform.T).dot(Y_prediction - self.Y)/self.m
            db = np.sum(Y_prediction - self.Y)/self.m

            # Updating weights
            self.w = self.w - dw * self.learning_rate
            self.b = self.b - db * self.learning_rate
        return self

    def update_weights(self):
        Y_prediction = self.predict(self.X)

        # Calculating gradients
        dw = -(X_transform.T).dot(self.Y - Y_prediction)/self.m

        db = -np.sum(self.Y - Y_prediction)/self.m

        # Updating weights
        self.w = self.w - self.learning_rate * dw
        self.b = self.b - self.learning_rate * db

    def predict(self, X):
        X_transform = self.transform(X)
        # X_normalize = self.normalize(X_transform)
        return np.dot(X_transform, self.w)

    def print_weights(self):
        print('Weights for the respective features are :')
        print(self.w)
        print()

        print('Bias value for the regression is:', self.b)
        print()

    def return_weights(self):
        return(self.w)

    def return_bias(self):
        return(self.b)

# %%
model = Polynomial_Regression(learning_rate=0.01, no_of_itr=500, degree=2)
model.fit(x_train, y_train)
# model.print_weights()
# weights = model.return_weights()
# bias = model.return_bias()
# print("r2 score is:", r2_score(y_test, model.predict(x_test)))
# print("MSE is:", mean_squared_error(y_test, model.predict(x_test)))
# print("RMSE is:", mean_squared_error(y_test, model.predict(x_test), squared=False))

# plt.scatter(model.predict(x_test), y_test)
# plt.xlabel('Predicted Price')
# plt.ylabel('Actual Price')
# plt.title('Polynomial Regression')
# plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()])

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11132\1516196169.py in <module>
#       1 model = Polynomial_Regression(learning_rate=0.01, no_of_itr=500, degree=2)
# ----> 2 model.fit(x_train, y_train)
#       3 # model.print_weights()
#       4 # weights = model.return_weights()
#       5 # bias = model.return_bias()
#
# ~\AppData\Local\Temp\ipykernel_11132\3758032214.py in fit(self, X, Y)
#      52
#      53             # Updating weights
# ---> 54             self.w = self.w - dw * self.learning_rate
#      55             self.b = self.b - db * self.learning_rate
#      56         return self
#
# ValueError: operands could not be broadcast together with shapes (3,) (3,1128)
